# %% [markdown]
# <a href="https://colab.research.google.com/github/azrapatvi/nlp_practice/blob/main/7_named_entity_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence="The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures."

sentence
# Out:
# 'The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures.'

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

words=word_tokenize(sentence)

words
# Out:
# ['The',
#  'Eiffel',
#  'Tower',
#  'was',
#  'built',
#  'from',
#  '1887',
#  'to',
#  '1889',
#  'by',
#  'French',
#  'engineer',
#  'Gustave',
#  'Eiffel',
#  ',',
#  'whose',
#  'company',
#  'specialized',
#  'in',
#  'building',
#  'metal',
#  'frameworks',
#  'and',
#  'structures',
#  '.']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
pos_tags=nltk.pos_tag(words)
pos_tags
# Out:
# [('The', 'DT'),
#  ('Eiffel', 'NNP'),
#  ('Tower', 'NNP'),
#  ('was', 'VBD'),
#  ('built', 'VBN'),
#  ('from', 'IN'),
#  ('1887', 'CD'),
#  ('to', 'TO'),
#  ('1889', 'CD'),
#  ('by', 'IN'),
#  ('French', 'JJ'),
#  ('engineer', 'NN'),
#  ('Gustave', 'NNP'),
#  ('Eiffel', 'NNP'),
#  (',', ','),
#  ('whose', 'WP$'),
#  ('company', 'NN'),
#  ('specialized', 'VBD'),
#  ('in', 'IN'),
#  ('building', 'NN'),
#  ('metal', 'NN'),
#  ('frameworks', 'NNS'),
#  ('and', 'CC'),
#  ('structures', 'NNS'),
#  ('.', '.')]

# %%
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
# named eneity recogniton
# means identifying or finding named entity or real word entity from the sentences
# named entites means person names,date,time, organization,etc

named_entities = nltk.ne_chunk(pos_tags)

print(named_entities)
# Out:
# (S
#   The/DT
#   (ORGANIZATION Eiffel/NNP Tower/NNP)
#   was/VBD
#   built/VBN
#   from/IN
#   1887/CD
#   to/TO
#   1889/CD
#   by/IN
#   (GPE French/JJ)
#   engineer/NN
#   (PERSON Gustave/NNP Eiffel/NNP)
#   ,/,
#   whose/WP$
#   company/NN
#   specialized/VBD
#   in/IN
#   building/NN
#   metal/NN
#   frameworks/NNS
#   and/CC
#   structures/NNS
#   ./.)

# %%
# !pip install svgling

# %%
named_entities = nltk.ne_chunk(pos_tags)

from IPython.display import display

display(named_entities)
# Out:
# Tree('S', [('The', 'DT'), Tree('ORGANIZATION', [('Eiffel', 'NNP'), ('Tower', 'NNP')]), ('was', 'VBD'), ('built', 'VBN'), ('from', 'IN'), ('1887', 'CD'), ('to', 'TO'), ('1889', 'CD'), ('by', 'IN'), Tree('GPE', [('French', 'JJ')]), ('engineer', 'NN'), Tree('PERSON', [('Gustave', 'NNP'), ('Eiffel', 'NNP')]), (',', ','), ('whose', 'WP$'), ('company', 'NN'), ('specialized', 'VBD'), ('in', 'IN'), ('building', 'NN'), ('metal', 'NN'), ('frameworks', 'NNS'), ('and', 'CC'), ('structures', 'NNS'), ('.', '.')])
